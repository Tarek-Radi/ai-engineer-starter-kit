# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# e:\Ai HCC\ai-engineer-starter-kit\.venv\Scripts\python.exe
# 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]

# %%
import requests
from transformers import pipeline

print("Environment is ready.")
# Out:
# Environment is ready.

# %%
sentiment_analyzer = pipeline("sentiment-analysis")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
result = sentiment_analyzer("I love HCC")
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998534917831421}]

# %%
result = sentiment_analyzer("I hate dealing with Israel")
print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.997212827205658}]

# %%
url = "https://dummyjson.com/quotes/random"

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data = response.json()
print(data)
# Out:
# {'id': 1378, 'quote': 'Let Every Eye Negotiate For Itself And Trust No Agent.', 'author': 'William Shakespeare'}

# %%
quote_text = data["quote"]
print(quote_text)
result = sentiment_analyzer(quote_text)
print(result)
# Out:
# Let Every Eye Negotiate For Itself And Trust No Agent.
# [{'label': 'NEGATIVE', 'score': 0.680605947971344}]
